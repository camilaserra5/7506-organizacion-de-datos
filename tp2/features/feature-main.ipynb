# %%
import pandas as pd
import numpy as np
import datetime
import utils
import os
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %%
def add_features(events, features, on='id', how = 'left'):
    """Hace un merge de features a events"""
    return pd.merge(events, features, on=on, how = how)

def merge_features(list):
    feature_final = list[0]
    list.pop(0)
    for features in list:
        feature_final = add_features(feature_final,features)
    return feature_final

# %%
# %run ./features_basicos.ipynb
# %run ./features_ambientes.ipynb
# %run ./features_amenities.ipynb
# %run ./features_metros.ipynb
# %run ./features_descripcion.ipynb
# %run ./features_direccion.ipynb
# %run ./features_dolar.ipynb
# %run ./features_relaciones.ipynb
# %run ./features_precio_x_direccion.ipynb

# %%
features_basicos = pd.read_csv('features_basicos.csv', low_memory=False)
features_ambientes = pd.read_csv('features_ambientes.csv', low_memory=False)
features_amenities = pd.read_csv('features_amenities.csv', low_memory=False)
features_metros = pd.read_csv('features_metros.csv', low_memory=False)
features_descripcion = pd.read_csv('features_descripcion.csv', low_memory=False)
features_direccion = pd.read_csv('features_direccion.csv', low_memory=False)
features_dolar = pd.read_csv('features_dolar.csv', low_memory=False)
features_relaciones = pd.read_csv('features_relaciones.csv', low_memory=False)
features_precio_x_direccion = pd.read_csv('features_precio_x_direccion.csv', low_memory=False)

# %%
features = merge_features([features_basicos,
                           features_ambientes,
                           features_amenities,
                           features_metros,
                           features_descripcion,
                           features_direccion,
                           features_dolar,
                           features_relaciones,
                           features_precio_x_direccion
                                 ])

features.fillna(value=0, inplace=True)
features.head()
# Out:
#        id  days_to_today   año  antiguedad  centroscomercialescercanos  \
# 0  254099           1564  2015         0.0                         0.0
# 1   53461           2350  2013        10.0                         1.0
# 2  247984           1509  2015         5.0                         0.0
# 3  209067           2826  2012         1.0                         1.0
# 4  185997           1275  2016        10.0                         0.0
#
#    escuelascercanas  habitaciones  garages  banos  anio  ...    dolar  \
# 0               0.0           2.0      1.0    2.0  2015  ...  16.7522
# 1               1.0           3.0      2.0    2.0  2013  ...  12.9460
# 2               0.0           3.0      2.0    2.0  2015  ...  16.5000
# 3               1.0           2.0      1.0    1.0  2012  ...  12.8070
# 4               0.0           2.0      1.0    1.0  2016  ...  18.2800
#
#    habxmetros  habxmetroscub  banosxmetros  banosxmetroscub  banosxhab  \
# 0    0.025000       0.025000      0.025000         0.025000        2.0
# 1    0.016667       0.011194      0.011111         0.007463        1.5
# 2    0.018072       0.020833      0.012048         0.013889        1.5
# 3    0.029851       0.031746      0.014925         0.015873        2.0
# 4    0.021053       0.021053      0.010526         0.010526        2.0
#
#    largotitulo  precio_ciudad  precio_provincia  precio_idzona
# 0         17.0   3.384659e+06      3.471705e+06   3.036895e+06
# 1         30.0   4.605869e+06      3.471705e+06   3.430078e+06
# 2         37.0   8.870115e+05      2.367694e+06   1.040921e+06
# 3         71.0   1.472305e+06      2.762465e+06   1.545000e+06
# 4         14.0   2.749675e+06      2.367694e+06   1.938494e+06
#
# [5 rows x 108 columns]

# %%
## esto genera un csv final con todos los features para usar en el modelo
features.to_csv('../modelos/data_set.csv', index=False)

# %%
features.shape
# Out:
# (300000, 108)

# %%
# Out:
# ['id',
#  'days_to_today',
#  'año',
#  'antiguedad',
#  'centroscomercialescercanos',
#  'escuelascercanas',
#  'habitaciones',
#  'garages',
#  'banos',
#  'anio',
#  'Apartamento',
#  'Bodega comercial',
#  'Casa',
#  'Casa en condominio',
#  'Casa uso de suelo',
#  'Departamento Compartido',
#  'Duplex',
#  'Edificio',
#  'Garage',
#  'Hospedaje',
#  'Huerta',
#  'Inmuebles productivos urbanos',
#  'Local Comercial',
#  'Local en centro comercial',
#  'Lote',
#  'Nave industrial',
#  'Oficina comercial',
#  'Otros',
#  'Quinta Vacacional',
#  'Rancho',
#  'Terreno',
#  'Terreno comercial',
#  'Terreno industrial',
#  'Villa',
#  'gimnasio',
#  'usosmultiples',
#  'piscina',
#  'qty_of_extras',
#  'metroscubiertos',
#  'metrostotales',
#  'precio_x_metro_cub_ciudad',
#  'precio_x_metro_tot_ciudad',
#  'precio_x_metro_cub_provincia',
#  'precio_x_metro_tot_provincia',
#  'precio_x_metro_cub_idzona',
#  'precio_x_metro_tot_idzona',
#  'precio_x_metro_cub_tipodepropiedad',
#  'precio_x_metro_tot_tipodepropiedad',
#  'popular_desc_1',
#  'popular_desc_2',
#  'popular_desc_3',
#  'popular_desc_4',
#  'popular_desc_5',
#  'popular_desc_6',
#  'popular_desc_7',
#  'popular_desc_8',
#  'popular_desc_9',
#  'popular_desc_10',
#  'popular_desc_11',
#  'popular_desc_12',
#  'popular_desc_13',
#  'idzona',
#  'lat',
#  'lng',
#  'avenue',
#  'Aguascalientes',
#  'Baja California Norte',
#  'Baja California Sur',
#  'Campeche',
#  'Chiapas',
#  'Chihuahua',
#  'Coahuila',
#  'Colima',
#  'Distrito Federal',
#  'Durango',
#  'Edo. de México',
#  'Guanajuato',
#  'Guerrero',
#  'Hidalgo',
#  'Jalisco',
#  'Michoacán',
#  'Morelos',
#  'Nayarit',
#  'Nuevo León',
#  'Oaxaca',
#  'Puebla',
#  'Querétaro',
#  'Quintana Roo',
#  'San luis Potosí',
#  'Sinaloa',
#  'Sonora',
#  'Tabasco',
#  'Tamaulipas',
#  'Tlaxcala',
#  'Veracruz',
#  'Yucatán',
#  'Zacatecas',
#  'periodo',
#  'dolar',
#  'habxmetros',
#  'habxmetroscub',
#  'banosxmetros',
#  'banosxmetroscub',
#  'banosxhab',
#  'largotitulo',
#  'precio_ciudad',
#  'precio_provincia',
#  'precio_idzona']
