# %%
# Importamos librerías de análisis de datos
import numpy as np
import pandas as pd

# plots
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
# %matplotlib inline

# %%
# Cargamos el dataframe
df = pd.read_csv('train.csv', index_col='id', parse_dates=['fecha'])

# %%
# nos quedamos con las columnas que nos interesan
df = df[['tipodepropiedad', 'escuelascercanas', 'centroscomercialescercanos', 'precio']]
df.head(2)
# Out:
#            tipodepropiedad  escuelascercanas  centroscomercialescercanos  \
# id
# 254099         Apartamento               0.0                         0.0
# 53461   Casa en condominio               1.0                         1.0
#
#            precio
# id
# 254099  2273000.0
# 53461   3600000.0

# %%
df.sort_values(by = ['precio'], ascending = False)
# Out:
#           tipodepropiedad  escuelascercanas  centroscomercialescercanos  \
# id
# 153761  Oficina comercial               0.0                         0.0
# 181271               Casa               1.0                         1.0
# 64975         Apartamento               1.0                         1.0
# 279973        Apartamento               1.0                         1.0
# 165404               Casa               1.0                         1.0
# ...                   ...               ...                         ...
# 258087        Apartamento               1.0                         1.0
# 149710        Apartamento               1.0                         1.0
# 167048               Casa               0.0                         0.0
# 207175               Casa               1.0                         1.0
# 136953        Apartamento               1.0                         1.0
#
#             precio
# id
# 153761  12525000.0
# 181271  12521000.0
# 64975   12520000.0
# ...

# %%
grouped = df.groupby('tipodepropiedad').agg({'escuelascercanas':'mean','centroscomercialescercanos':'mean', 'precio':'mean'})
grouped
# Out:
#                                escuelascercanas  centroscomercialescercanos  \
# tipodepropiedad
# Apartamento                            0.458921                    0.450847
# Bodega comercial                       0.156472                    0.168563
# Casa                                   0.455506                    0.385564
# Casa en condominio                     0.498730                    0.459605
# Casa uso de suelo                      0.326271                    0.316384
# Departamento Compartido                0.609929                    0.666667
# Duplex                                 0.011662                    0.008746
# Edificio                               0.305874                    0.313754
# Garage                                 0.000000                    0.000000
# Hospedaje                              0.000000                    0.000000
# Huerta                                 0.100000                    0.150000
# ...

# %%
grouped.sort_values(by = ['precio'], ascending = False)
# Out:
#                                escuelascercanas  centroscomercialescercanos  \
# tipodepropiedad
# Edificio                               0.305874                    0.313754
# Rancho                                 0.088235                    0.058824
# Inmuebles productivos urbanos          0.495000                    0.440000
# Nave industrial                        0.000000                    0.000000
# Casa uso de suelo                      0.326271                    0.316384
# Terreno industrial                     0.000000                    0.000000
# Huerta                                 0.100000                    0.150000
# Quinta Vacacional                      0.144304                    0.101266
# Oficina comercial                      0.240666                    0.291786
# Hospedaje                              0.000000                    0.000000
# Casa en condominio                     0.498730                    0.459605
# ...
